# %%
#Mahdi Saieedi
# student_number = 401207254

# %%
#reading the data
import pandas as pd
import numpy as np
Data = pd.read_csv("/content/Dataset.csv")

# %%
len(Data)
# Out:
# 768

# %%
Data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            7      160             54             32      175  30.5
# 1            5      115             98              0        0  52.9
# 2            5      189             64             33      325  31.2
# 3            1      173             74              0        0  36.8
# 4            6      124             72              0        0  27.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.588   39     True
# 1                     0.209   28     True
# 2                     0.583   29     True
# 3                     0.088   38     True
# 4                     0.368   29     True

# %%
#data preparation
Data.drop(Data[Data['BMI'] == 0].index, inplace=True)
len(Data)
# Out:
# 757

# %%
Data.drop(Data[Data['Glucose'] == 0].index, inplace=True)
len(Data)
# Out:
# 752

# %%
Data.drop(Data[Data['BloodPressure'] == 0].index, inplace=True)
len(Data)
# Out:
# 724

# %%
type(Data['Outcome'][0])
# Out:
# numpy.bool_

# %%
Data = Data.reset_index(drop=True)

# %%
for i in range(len(Data)):
  if Data['Outcome'][i] == np.bool_(True) :
    Data['Outcome'][i] = 1
  if Data['Outcome'][i] == np.bool_(False) :
    Data['Outcome'][i] = -1
# Out:
# <ipython-input-46-e0018b9b9b67>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Outcome'][i] = 1
# <ipython-input-46-e0018b9b9b67>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Outcome'][i] = -1

# %%
Data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              7      160             54             32      175  30.5
# 1              5      115             98              0        0  52.9
# 2              5      189             64             33      325  31.2
# 3              1      173             74              0        0  36.8
# 4              6      124             72              0        0  27.6
# ..           ...      ...            ...            ...      ...   ...
# 719            0      177             60             29      478  34.6
# 720            1      193             50             16      375  25.9
# 721            1      100             66             15       56  23.6
# 722            5      143             78              0        0  45.0
# 723            4      184             78             39      277  37.0
#
#      DiabetesPedigreeFunction  Age Outcome
# 0                       0.588   39       1
# ...

# %%
df_scaled = (Data - Data.min()) / (Data.max() - Data.min())

# %%
df_scaled
# Out:
#     Pregnancies   Glucose BloodPressure SkinThickness   Insulin       BMI  \
# 0      0.411765  0.748387      0.306122      0.323232  0.206856  0.251534
# 1      0.294118  0.458065      0.755102           0.0       0.0  0.709611
# 2      0.294118  0.935484      0.408163      0.333333  0.384161  0.265849
# 3      0.058824  0.832258      0.510204           0.0       0.0  0.380368
# 4      0.352941  0.516129      0.489796           0.0       0.0  0.192229
# ..          ...       ...           ...           ...       ...       ...
# 719         0.0  0.858065      0.367347      0.292929  0.565012  0.335378
# 720    0.058824   0.96129      0.265306      0.161616  0.443262  0.157464
# 721    0.058824   0.36129      0.428571      0.151515  0.066194  0.110429
# 722    0.294118   0.63871       0.55102           0.0       0.0  0.548057
# 723    0.235294  0.903226       0.55102      0.393939  0.327423  0.384458
#
#     DiabetesPedigreeFunction       Age Outcome
# ...

# %%
df_scaled.drop('Outcome', axis=1, inplace=True)
df_scaled
# Out:
#     Pregnancies   Glucose BloodPressure SkinThickness   Insulin       BMI  \
# 0      0.411765  0.748387      0.306122      0.323232  0.206856  0.251534
# 1      0.294118  0.458065      0.755102           0.0       0.0  0.709611
# 2      0.294118  0.935484      0.408163      0.333333  0.384161  0.265849
# 3      0.058824  0.832258      0.510204           0.0       0.0  0.380368
# 4      0.352941  0.516129      0.489796           0.0       0.0  0.192229
# ..          ...       ...           ...           ...       ...       ...
# 719         0.0  0.858065      0.367347      0.292929  0.565012  0.335378
# 720    0.058824   0.96129      0.265306      0.161616  0.443262  0.157464
# 721    0.058824   0.36129      0.428571      0.151515  0.066194  0.110429
# 722    0.294118   0.63871       0.55102           0.0       0.0  0.548057
# 723    0.235294  0.903226       0.55102      0.393939  0.327423  0.384458
#
#     DiabetesPedigreeFunction       Age
# 0                   0.217763       0.3
# ...

# %%
df_scaled['Outcome'] = Data['Outcome']
df_scaled
# Out:
#     Pregnancies   Glucose BloodPressure SkinThickness   Insulin       BMI  \
# 0      0.058824  0.470968      0.367347      0.232323  0.125296  0.319018
# 1      0.176471  0.445161      0.265306       0.10101  0.100473  0.231084
# 2      0.058824  0.380645      0.061224      0.383838  0.098109  0.513292
# 3      0.294118  0.496774      0.489796      0.232323  0.132388  0.163599
# 4      0.058824  0.341935       0.44898      0.212121       0.0  0.184049
# ..          ...       ...           ...           ...       ...       ...
# 719    0.176471  0.432258      0.326531      0.393939       0.0  0.243354
# 720    0.235294  0.470968      0.387755      0.121212       0.0  0.235174
# 721    0.294118  0.283871      0.428571      0.212121  0.027187  0.126789
# 722    0.352941       0.6      0.377551           0.0       0.0  0.122699
# 723    0.294118  0.458065      0.755102           0.0       0.0  0.709611
#
#     DiabetesPedigreeFunction       Age Outcome
# ...

# %%
df_scaled = df_scaled.sample(frac=1)
df_scaled = df_scaled.reset_index(drop=True)
df_scaled
# Out:
#     Pregnancies   Glucose BloodPressure SkinThickness   Insulin       BMI  \
# 0      0.058824  0.309677      0.387755      0.252525  0.048463  0.026585
# 1      0.294118  0.735484      0.612245      0.414141  0.248227  0.433538
# 2      0.588235  0.522581      0.469388      0.262626  0.135934  0.263804
# 3      0.235294  0.303226      0.469388      0.323232  0.104019  0.304703
# 4      0.176471  0.458065      0.428571      0.393939  0.165485  0.406953
# ..          ...       ...           ...           ...       ...       ...
# 719         0.0  0.387097      0.408163      0.232323  0.137116  0.196319
# 720    0.176471  0.541935      0.489796      0.252525  0.224586  0.290389
# 721         0.0  0.606452      0.367347      0.353535    0.1974  0.335378
# 722    0.470588  0.574194      0.489796           0.0       0.0  0.300613
# 723    0.176471  0.806452      0.510204      0.191919  0.147754  0.239264
#
#     DiabetesPedigreeFunction       Age Outcome
# ...

# %%
# class Perceptron:
#   def __init__(self, learning_rate=0.01, n_iters=1000):
#     self.lr = learning_rate
#     self.n_iters = n_iters
#     self.activation_func = self._unit_step_func
#     self.weights = None
#     self.bias = None

#   def fit(self, X, y):
#     n_samples, n_features = X.shape
#     # init parameters
#     self.weights = np.zeros(n_features)
#     self.weights = self.weights.astype(float)
#     self.bias = 0

#     y_ = np.array([1 if i > 0 else 0 for i in y])

#     for _ in range(self.n_iters):
#       for idx, x_i in enumerate(X):
#         linear_output = np.dot(x_i, self.weights) + self.bias
#         y_predicted = self.activation_func(linear_output)

#         # Perceptron update rule
#         update = self.lr * (y_[idx] - y_predicted)
#         update  = update.astype(float)
#         self.weights += update * x_i
#         self.bias += update

#   def predict(self, X):
#     linear_output = np.dot(X, self.weights) + self.bias
#     y_predicted = self.activation_func(linear_output)
#     return y_predicted

#   def _unit_step_func(self, x):
#     return np.where(x>=0, 1, 0)

# %%
# class Perceptron:

#     def __init__(self, learning_rate=0.01, epochs=1000):
#         self.lr = learning_rate
#         self.epochs = epochs
#         self.weights = None
#         self.bias = None

#     def fit(self, X, y):
#         n_samples, n_features = X.shape

#         # initialize parameters
#         self.weights = np.zeros(n_features)
#         # self.weights = self.weights.astype(float)
#         self.bias = 0

#         y_ = np.array([1 if i > 0 else 0 for i in y])
#         # y_ = y_.astype(float)

#         for _ in range(self.epochs):
#             for idx, x_i in enumerate(X):
#                 linear_output = np.dot(x_i, self.weights) + self.bias
#                 y_predicted = self._activate(linear_output)

#                 # Perceptron update
#                 update = self.lr * (y_[idx] - y_predicted)
#                 self.weights += update * x_i
#                 self.bias += update

#     def _activate(self, x):
#         return 1 if x >= 0 else 0

#     def predict(self, X):
#         linear_output = np.dot(X, self.weights) + self.bias
#         y_predicted = self._activate(linear_output)
#         return y_predicted

# %%
# class Perceptron():
#     def __init__(self, learning_rate = .01, n_iterations = 1000):
#         self.learning_rate = learning_rate
#         self.n_iterations = n_iterations
#         self.bias = None
#         self.weights = None


#     def activation_function(self, net_input):
#         # STEP ACTIVATION
#         return np.where(net_input > 0, 1, 0)


#     def fit(self, features, targets):
#         n_examples, n_features = features.shape

#         # change these to use different initialization scheme
#         self.weights = np.random.uniform(size = n_features, low = -0.5, high = 0.5)
#         self.bias = np.random.uniform(low = -0.5, high = 0.5)

#         for _ in range(self.n_iterations):
#             for example_index, example_features in enumerate(features):
#                 net_input = np.dot(example_features, self.weights) + self.bias
#                 y_predicted = self.activation_function(net_input)
#                 self._update_weights(example_features, targets[example_index], y_predicted)


#     def _update_weights(self, example_features, y_actual, y_predicted):
#         error = y_actual - y_predicted
#         weight_correction = self.learning_rate * error
#         self.weights = self.weights + weight_correction * example_features
#         self.bias = self.bias + weight_correction

#     def predict(self, features):
#         net_input = np.dot(features, self.weights) + self.bias
#         y_predicted = self.activation_function(net_input)
#         return y_predicted

# %%
# for i in range(len(df_scaled)):
#   df_scaled['Outcome'][i] = df_scaled['Outcome'][i].astype(float)

# %%
X_train = df_scaled[0:650]

# %%
X_train
# Out:
#     Pregnancies   Glucose BloodPressure SkinThickness   Insulin       BMI  \
# 0      0.058824  0.309677      0.387755      0.252525  0.048463  0.026585
# 1      0.294118  0.735484      0.612245      0.414141  0.248227  0.433538
# 2      0.588235  0.522581      0.469388      0.262626  0.135934  0.263804
# 3      0.235294  0.303226      0.469388      0.323232  0.104019  0.304703
# 4      0.176471  0.458065      0.428571      0.393939  0.165485  0.406953
# ..          ...       ...           ...           ...       ...       ...
# 645    0.176471  0.354839      0.387755      0.191919   0.08747   0.07362
# 646    0.352941  0.670968      0.489796      0.353535       0.0  0.314928
# 647    0.352941  0.664516      0.571429           0.0       0.0  0.231084
# 648    0.117647   0.23871      0.489796      0.151515  0.089835  0.243354
# 649    0.058824  0.380645      0.061224      0.383838  0.098109  0.513292
#
#     DiabetesPedigreeFunction       Age Outcome
# ...

# %%
X_train.drop('Outcome', axis=1, inplace=True)
# Out:
# <ipython-input-212-afa568a04d57>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop('Outcome', axis=1, inplace=True)

# %%
X_train
# Out:
#     Pregnancies   Glucose BloodPressure SkinThickness   Insulin       BMI  \
# 0      0.058824  0.309677      0.387755      0.252525  0.048463  0.026585
# 1      0.294118  0.735484      0.612245      0.414141  0.248227  0.433538
# 2      0.588235  0.522581      0.469388      0.262626  0.135934  0.263804
# 3      0.235294  0.303226      0.469388      0.323232  0.104019  0.304703
# 4      0.176471  0.458065      0.428571      0.393939  0.165485  0.406953
# ..          ...       ...           ...           ...       ...       ...
# 645    0.176471  0.354839      0.387755      0.191919   0.08747   0.07362
# 646    0.352941  0.670968      0.489796      0.353535       0.0  0.314928
# 647    0.352941  0.664516      0.571429           0.0       0.0  0.231084
# 648    0.117647   0.23871      0.489796      0.151515  0.089835  0.243354
# 649    0.058824  0.380645      0.061224      0.383838  0.098109  0.513292
#
#     DiabetesPedigreeFunction       Age
# 0                   0.172502  0.066667
# ...

# %%
Y_train = df_scaled['Outcome'][0:650]

# %%
Y_train
# Out:
# 0       1
# 1       1
# 2      -1
# 3       1
# 4       1
#        ..
# 645     1
# 646    -1
# 647    -1
# 648    -1
# 649     1
# Name: Outcome, Length: 650, dtype: object

# %%
X_train.shape
# Out:
# (650, 8)

# %%
class Perceptron:
    def __init__(self):
        self.weights=[]

    #activation function
    def activation(self,data):
        activation_val=np.dot(self.weights,data)
        return 1 if activation_val>=0 else 0

    def fit(self,X,y,lrate,epochs):
        self.weights=[0.0 for i in range(len(X.columns))]
        #no.of iterations to train the neural network
        for epoch in range(epochs):
            print(str(epoch+1),"epoch has started...")
            for index in range(len(X)):
                x=X.iloc[index]
                predicted=self.activation(x)
                #check for misclassification
                if(y.iloc[index]==predicted):
                    pass
                else:
                    #calculate the error value
                    error=y.iloc[index]-predicted
                    #updation of associated self.weights acccording to Perceptron training rule
                    for j in range(len(x)):
                        self.weights[j] -=self.weights[j]+lrate*error*x[j]

    #training perceptron for the given data
    def predict(self,x_test):
        predicted=[]
        for i in range(len(x_test)):
            #prediction for test set using obtained weights
            predicted.append(self.activation(x_test.iloc[i]))
        return predicted

    def accuracy(self,predicted,original):
        correct=0
        lent=len(predicted)
        for i in range(lent):
            if(predicted[i]==original.iloc[i]):
                correct+=1
        return (correct/lent)*100

    def getweights(self):
        return self.weights

# %%
model = Perceptron()

# %%
model.fit(X_train, Y_train , 0.01,50)
# Out:
# 1 epoch has started...
# 2 epoch has started...
# 3 epoch has started...
# 4 epoch has started...
# 5 epoch has started...
# 6 epoch has started...
# 7 epoch has started...
# 8 epoch has started...
# 9 epoch has started...
# 10 epoch has started...
# 11 epoch has started...
# 12 epoch has started...
# 13 epoch has started...
# 14 epoch has started...
# 15 epoch has started...
# 16 epoch has started...
# 17 epoch has started...
# 18 epoch has started...
# 19 epoch has started...
# 20 epoch has started...
# 21 epoch has started...
# 22 epoch has started...
# 23 epoch has started...
# 24 epoch has started...
# 25 epoch has started...
# 26 epoch has started...
# 27 epoch has started...
# 28 epoch has started...
# 29 epoch has started...
# 30 epoch has started...
# 31 epoch has started...
# 32 epoch has started...
# 33 epoch has started...
# 34 epoch has started...
# 35 epoch has started...
# 36 epoch has started...
# 37 epoch has started...
# 38 epoch has started...
# ...

# %%
X_test = df_scaled[650:]
X_test.drop('Outcome', axis=1, inplace=True)
Y_test = df_scaled['Outcome'][650:]
# Out:
# <ipython-input-272-877aa389d4d0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop('Outcome', axis=1, inplace=True)

# %%
pred=model.predict(X_test)

# %%
print("accuracy: ",model.accuracy(pred,Y_test))
# Out:
# accuracy:  28.37837837837838

# %%
print("weights: ",model.getweights())
# Out:
# weights:  [0.002352941176470589, 0.004774193548387097, 0.009795918367346938, 0.0030303030303030303, 0.0017966903073286054, 0.004867075664621678, 0.004005123825789923, 0.001333333333333334]

# %%
df_scaled
# Out:
#     Pregnancies   Glucose BloodPressure SkinThickness   Insulin       BMI  \
# 0      0.058824  0.309677      0.387755      0.252525  0.048463  0.026585
# 1      0.294118  0.735484      0.612245      0.414141  0.248227  0.433538
# 2      0.588235  0.522581      0.469388      0.262626  0.135934  0.263804
# 3      0.235294  0.303226      0.469388      0.323232  0.104019  0.304703
# 4      0.176471  0.458065      0.428571      0.393939  0.165485  0.406953
# ..          ...       ...           ...           ...       ...       ...
# 719         0.0  0.387097      0.408163      0.232323  0.137116  0.196319
# 720    0.176471  0.541935      0.489796      0.252525  0.224586  0.290389
# 721         0.0  0.606452      0.367347      0.353535    0.1974  0.335378
# 722    0.470588  0.574194      0.489796           0.0       0.0  0.300613
# 723    0.176471  0.806452      0.510204      0.191919  0.147754  0.239264
#
#     DiabetesPedigreeFunction       Age Outcome
# ...

# %%
from sklearn.model_selection import train_test_split
data2 = df_scaled
classes=data2["Outcome"]
data2=data2.drop(columns="Outcome")
x_train,x_test,y_train,y_test=train_test_split(data2,classes)

# %%
model2=Perceptron()
model2.fit(x_train,y_train,0.01,500)
pred2=model2.predict(x_test)
# Out:
# 1 epoch has started...
# 2 epoch has started...
# 3 epoch has started...
# 4 epoch has started...
# 5 epoch has started...
# 6 epoch has started...
# 7 epoch has started...
# 8 epoch has started...
# 9 epoch has started...
# 10 epoch has started...
# 11 epoch has started...
# 12 epoch has started...
# 13 epoch has started...
# 14 epoch has started...
# 15 epoch has started...
# 16 epoch has started...
# 17 epoch has started...
# 18 epoch has started...
# 19 epoch has started...
# 20 epoch has started...
# 21 epoch has started...
# 22 epoch has started...
# 23 epoch has started...
# 24 epoch has started...
# 25 epoch has started...
# 26 epoch has started...
# 27 epoch has started...
# 28 epoch has started...
# 29 epoch has started...
# 30 epoch has started...
# 31 epoch has started...
# 32 epoch has started...
# 33 epoch has started...
# 34 epoch has started...
# 35 epoch has started...
# 36 epoch has started...
# 37 epoch has started...
# 38 epoch has started...
# ...

# %%
print("accuracy: ",model2.accuracy(pred2,y_test))
print("weights: ",model2.getweights())
# Out:
# accuracy:  30.386740331491712
# weights:  [0.0011764705882352942, 0.013290322580645162, 0.014285714285714287, 0.008282828282828282, 0.0, 0.012719836400817999, 0.002391118701964133, 0.002]
